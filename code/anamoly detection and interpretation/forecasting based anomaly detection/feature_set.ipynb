# %%
import pandas as pd
df = pd.read_csv(r'C:\DATA ANALYSIS AND DATA SCIENCE PROJECTS\Multi Scale Energy Stress Analysis\data\grid_final_feature_set.csv')

# %%
df.columns
# Out:
# Index(['temp_c', 'humidity_pct', 'wind_speed_ms', 'dhi_wm2', 'solar_gen_mw',
#        'wind_gen_mw', 'demand_avg_mw', 'demand_std_mw', 'hour_sin', 'hour_cos',
#        'demand_ramp', 'demand_lag_1h', 'net_load_lag_24h', 'temp_rolling_3h',
#        'demand_volatility_6h', 'solar_penetration',
#        'total_renewable_penetration', 'heat_index_c', 'demand_lag_24h',
#        'demand_lag_168h', 'net_load_lag_1h', 'temp_lag_24h',
#        'wind_gen_lag_24h', 'demand_rolling_std_7d', 'demand_rolling_max_24h',
#        'temp_rolling_mean_7d', 'temp_rolling_max_3d', 'solar_rolling_mean_7d',
#        'wind_rolling_std_24h', 'cooling_degree_hours', 'heating_degree_hours',
#        'demand_percentile_rank', 'is_extreme_demand', 'is_extreme_temp',
#        'low_ren_high_dem', 'net_load_ramp', 'solar_ramp', 'wind_ramp',
#        'renewable_ramp', 'month_sin', 'month_cos', 'heatwave_index',
#        'is_weekend', 'is_peak_hour', 'is_holiday', 'is_pre_holiday',
# ...

# %%
features = [
    'net_load_mw',
    'demand_avg_mw',
    'solar_gen_mw',
    'wind_gen_mw',
    'net_load_ramp',
    'demand_ramp',
    'solar_ramp',
    'wind_ramp',
    'renewable_ramp',
    'net_load_lag_1h',
    'net_load_lag_24h',
    'demand_lag_1h',
    'demand_lag_24h',
    'wind_gen_lag_24h',
    'demand_volatility_6h',
    'demand_rolling_std_7d',
    'solar_rolling_mean_7d',
    'wind_rolling_std_24h',
    'temp_c',
    'heat_index_c',
    'humidity_pct',
    'wind_speed_ms',
    'cooling_degree_hours',
    'heating_degree_hours',
    'heatwave_index',
    'solar_penetration',
    'total_renewable_penetration',
    'low_ren_high_dem',
    'hour_sin',
    'hour_cos',
    'month_sin',
    'month_cos',
    'is_peak_hour',
    'is_weekend',
    'is_extreme_demand',
    'is_extreme_temp',
    'demand_percentile_rank'
]

# %%
df_model = df[features].copy()
df_model.to_csv("forecasting_feature_set.csv", index=False)
